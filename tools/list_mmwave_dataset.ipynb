# %%
from os import listdir
from os.path import isfile, join

mypath = "/media/NAS/MMWAVE_1642_10days/source"
subjects = listdir(mypath)
subjects.sort()

for subject in subjects:
  print("\nSubject: {}, # Days: {}".format(subject, len(listdir(join(mypath, subject)))))
  for date in listdir(join(mypath, subject)):
    print("Date: {}, # Samples: {}".format(date, len(listdir(join(mypath, subject, date)))))
# Out:
# Subject: aali26, # Days: 10
# Date: 11_04, # Samples: 100
# Date: 11_26, # Samples: 100
# Date: 11_30, # Samples: 100
# Date: 12_02, # Samples: 100
# Date: 11_27, # Samples: 100
# Date: 11_29, # Samples: 100
# Date: 11_28, # Samples: 100
# Date: 11_20, # Samples: 100
# Date: 12_01, # Samples: 100
# Date: 12_09, # Samples: 100
#
# Subject: apandit5, # Days: 10
# Date: 11_07, # Samples: 100
# Date: 11_06, # Samples: 100
# Date: 10_21, # Samples: 100
# Date: 12_02, # Samples: 100
# Date: 10_16, # Samples: 100
# Date: 11_27, # Samples: 100
# Date: 12_18, # Samples: 100
# Date: 12_09, # Samples: 100
# Date: 11_18, # Samples: 100
# Date: 11_13, # Samples: 100
#
# Subject: arahman3, # Days: 10
# Date: 06_11, # Samples: 99
# Date: 06_26, # Samples: 100
# Date: 07_08, # Samples: 100
# Date: 07_09, # Samples: 100
# Date: 06_06, # Samples: 100
# Date: 06_25, # Samples: 100
# Date: 06_20, # Samples: 100
# Date: 07_18, # Samples: 100
# Date: 07_02, # Samples: 100
# Date: 06_19, # Samples: 100
#
# ...

# %%
from os import listdir
from os.path import isfile, join

mypath = "/media/NAS/MMWAVE_1642_10days/target/conf"
subjects = listdir(mypath)
subjects.sort()

for subject in subjects:
  print("\nSubject: {}, # Days: {}".format(subject, len(listdir(join(mypath, subject)))))
  for date in listdir(join(mypath, subject)):
    print("Date: {}, # Samples: {}".format(date, len(listdir(join(mypath, subject, date)))))
# Out:
# Subject: aali26, # Days: 5
# Date: 09_30, # Samples: 100
# Date: 10_01, # Samples: 100
# Date: 09_05, # Samples: 100
# Date: 09_10, # Samples: 100
# Date: 12_09, # Samples: 50
#
# Subject: apandit5, # Days: 6
# Date: 10_21, # Samples: 100
# Date: 09_26, # Samples: 100
# Date: 10_16, # Samples: 100
# Date: 09_25, # Samples: 100
# Date: 10_23, # Samples: 100
# Date: 10_30, # Samples: 100
#
# Subject: arahman3, # Days: 4
# Date: 08_06, # Samples: 50
# Date: 12_12, # Samples: 50
# Date: 07_24, # Samples: 50
# Date: 07_22, # Samples: 50
#
# Subject: hchen32, # Days: 5
# Date: 08_15, # Samples: 50
# Date: 08_14, # Samples: 50
# Date: 08_13, # Samples: 50
# Date: 09_16, # Samples: 100
# Date: 09_11, # Samples: 100
#
# Subject: hhah, # Days: 7
# Date: 09_30, # Samples: 100
# Date: 09_26, # Samples: 100
# Date: 09_19, # Samples: 100
# Date: 09_05, # Samples: 100
# Date: 09_27, # Samples: 100
# Date: 09_06, # Samples: 100
# Date: 09_11, # Samples: 100
#
# Subject: hmacharl, # Days: 5
# ...

# %%
from os import listdir
from os.path import isfile, join

mypath = "/media/NAS/MMWAVE_1642_10days/target/office"
subjects = listdir(mypath)
subjects.sort()

for subject in subjects:
  print("\nSubject: {}, # Days: {}".format(subject, len(listdir(join(mypath, subject)))))
  for date in listdir(join(mypath, subject)):
    print("Date: {}, # Samples: {}".format(date, len(listdir(join(mypath, subject, date)))))
# Out:
# Subject: aali26, # Days: 5
# Date: 11_30, # Samples: 100
# Date: 11_27, # Samples: 100
# Date: 11_29, # Samples: 100
# Date: 11_28, # Samples: 100
# Date: 12_01, # Samples: 100
#
# Subject: apandit5, # Days: 5
# Date: 12_10, # Samples: 50
# Date: 11_27, # Samples: 100
# Date: 12_18, # Samples: 50
# Date: 12_11, # Samples: 50
# Date: 12_09, # Samples: 50
#
# Subject: arahman3, # Days: 2
# Date: 08_14, # Samples: 50
# Date: 12_12, # Samples: 50
#
# Subject: hchen32, # Days: 2
# Date: 08_14, # Samples: 50
# Date: 08_16, # Samples: 50
#
# Subject: hhah, # Days: 5
# Date: 12_16, # Samples: 50
# Date: 12_12, # Samples: 50
# Date: 12_10, # Samples: 50
# Date: 12_11, # Samples: 50
# Date: 12_09, # Samples: 90
#
# Subject: hmacharl, # Days: 5
# Date: 12_08, # Samples: 50
# Date: 12_02, # Samples: 100
# Date: 12_07, # Samples: 50
# Date: 12_06, # Samples: 50
# Date: 12_09, # Samples: 50
#
# Subject: kjakkala, # Days: 5
# Date: 08_17, # Samples: 50
# Date: 08_14, # Samples: 50
# ...

# %%
from os import listdir
from os.path import isfile, join

mypath = "/media/NAS/MMWAVE_1642_10days/target/server"
subjects = listdir(mypath)
subjects.sort()

for subject in subjects:
  print("\nSubject: {}, # Days: {}".format(subject, len(listdir(join(mypath, subject)))))
  for date in listdir(join(mypath, subject)):
    print("Date: {}, # Samples: {}".format(date, len(listdir(join(mypath, subject, date)))))
# Out:
# Subject: aali26, # Days: 6
# Date: 09_22, # Samples: 100
# Date: 09_23, # Samples: 100
# Date: 11_30, # Samples: 50
# Date: 11_27, # Samples: 100
# Date: 10_01, # Samples: 100
# Date: 12_09, # Samples: 100
#
# Subject: apandit5, # Days: 5
# Date: 12_10, # Samples: 50
# Date: 11_27, # Samples: 100
# Date: 12_18, # Samples: 50
# Date: 12_11, # Samples: 50
# Date: 12_09, # Samples: 50
#
# Subject: arahman3, # Days: 4
# Date: 08_06, # Samples: 50
# Date: 07_23, # Samples: 50
# Date: 12_12, # Samples: 50
# Date: 07_22, # Samples: 50
#
# Subject: hchen32, # Days: 4
# Date: 08_15, # Samples: 50
# Date: 08_14, # Samples: 50
# Date: 08_13, # Samples: 50
# Date: 09_11, # Samples: 100
#
# Subject: hhah, # Days: 5
# Date: 12_16, # Samples: 50
# Date: 12_12, # Samples: 50
# Date: 12_10, # Samples: 50
# Date: 12_11, # Samples: 50
# Date: 12_09, # Samples: 50
#
# Subject: hmacharl, # Days: 5
# Date: 12_08, # Samples: 50
# Date: 12_10, # Samples: 50
# Date: 12_07, # Samples: 50
# ...
